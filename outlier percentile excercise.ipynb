# %%
import pandas as pd
df=pd.read_csv('C://Users//Bhavesh//airbnb_price_list.csv')
df.head()
# Out:
#      id                                              name  ...  calculated_host_listings_count availability_365
# 0  2539                Clean & quiet apt home by the park  ...                               6              365
# 1  2595                             Skylit Midtown Castle  ...                               2              355
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !  ...                               1              365
# 3  3831                   Cozy Entire Floor of Brownstone  ...                               1              194
# 4  5022  Entire Apt: Spacious Studio/Loft by central park  ...                               1                0
#
# [5 rows x 16 columns]

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df1=df.drop(['last_review','reviews_per_month'],axis='columns')

# %%
df1.shape
# Out:
# (48895, 14)

# %%
df1.isnull().sum()
# Out:
# id                                 0
# name                              16
# host_id                            0
# host_name                         21
# neighbourhood_group                0
# neighbourhood                      0
# latitude                           0
# longitude                          0
# room_type                          0
# price                              0
# minimum_nights                     0
# number_of_reviews                  0
# calculated_host_listings_count     0
# availability_365                   0
# dtype: int64

# %%
df2=df1.dropna()

# %%
df2.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
df2['price_per_night']=df2['price']/df2['minimum_nights']
df2.head()
# Out:
# C:\Users\Bhavesh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      id                                              name  ...  availability_365 price_per_night
# 0  2539                Clean & quiet apt home by the park  ...               365           149.0
# 1  2595                             Skylit Midtown Castle  ...               355           225.0
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !  ...               365            50.0
# 3  3831                   Cozy Entire Floor of Brownstone  ...               194            89.0
# 4  5022  Entire Apt: Spacious Studio/Loft by central park  ...                 0             8.0
#
# ...

# %%
df2.describe()
# Out:
#                  id       host_id      latitude  ...  calculated_host_listings_count  availability_365  price_per_night
# count  4.885800e+04  4.885800e+04  48858.000000  ...                    48858.000000      48858.000000     48858.000000
# mean   1.902335e+07  6.763169e+07     40.728941  ...                        7.148369        112.801425        70.169805
# std    1.098289e+07  7.862389e+07      0.054528  ...                       32.964600        131.610962       157.667627
# min    2.539000e+03  2.438000e+03     40.499790  ...                        1.000000          0.000000         0.000000
# 25%    9.475980e+06  7.818669e+06     40.690090  ...                        1.000000          0.000000        20.000000
# 50%    1.969114e+07  3.079133e+07     40.723070  ...                        1.000000         45.000000        44.500000
# 75%    2.915765e+07  1.074344e+08     40.763107  ...                        2.000000        227.000000        81.333333
# ...

# %%
len(df2[df2['price_per_night']>0])
# Out:
# 48858

# %%
df3=df2[df2['price_per_night']>0]

# %%
len(df3)
# Out:
# 48847

# %%
max_thresold=df3['price_per_night'].quantile(.99)
max_thresold
# Out:
# 443.0

# %%
min_thresold=df3['price_per_night'].quantile(.111)
min_thresold
# Out:
# 6.785714285714285

# %%
len(df3[df3['price_per_night']>=max_thresold])
#len(df3[df3['price_per_night']<=min_thresold])
# Out:
# 490

# %%
len(df3[(df3['price_per_night'] > min_thresold)& (df3['price_per_night']<max_thresold)])
# Out:
# 42937

# %%
df3
# Out:
# 48847

# %%
48847-5910
# Out:
# 42937

# %%
df3[df3['price_per_night']<=max_thresold].head(50)
# Out:
#        id                                               name  ...  availability_365 price_per_night
# 0    2539                 Clean & quiet apt home by the park  ...               365      149.000000
# 1    2595                              Skylit Midtown Castle  ...               355      225.000000
# 2    3647                THE VILLAGE OF HARLEM....NEW YORK !  ...               365       50.000000
# 3    3831                    Cozy Entire Floor of Brownstone  ...               194       89.000000
# 4    5022   Entire Apt: Spacious Studio/Loft by central park  ...                 0        8.000000
# 5    5099          Large Cozy 1 BR Apartment In Midtown East  ...               129       66.666667
# 6    5121                                    BlissArtsSpace!  ...                 0        1.333333
# 7    5178                   Large Furnished Room Near B'way   ...               220       39.500000
# ...
