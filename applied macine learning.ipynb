# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
#importin  fruits color data sets
fruits=pd.read_csv('C://Users//Bhavesh//fruits_color_data.txt',sep='\t')

# %%
fruits
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
#splitting this dataset into training and testing data set in the ratio of 75:25 with help of sklern
#this would help us to predict the fruit which would be not given in this data set

x=fruits[['height','width','mass','color_score']]
y=fruits[['fruit_label']]

x1_train,x1_test,y1_train,y1_test=train_test_split(x,y)

# %%
x_train
# Out:
#     height  width  mass  color_score
# 43    10.3    7.2   194         0.70
# 53     8.4    6.0   120         0.74
# 56     8.1    5.9   116         0.73
# 24     9.4    9.0   342         0.75
# 27     9.2    7.5   204         0.77
# 20     7.5    7.5   160         0.86
# 15     7.1    7.7   156         0.69
# 19     7.2    7.4   162         0.85
# 50     8.2    6.0   130         0.71
# 26     9.2    9.6   362         0.74
# 0      7.3    8.4   192         0.55
# 1      6.8    8.0   180         0.59
# 37     7.3    7.3   154         0.79
# 11     7.6    7.1   172         0.92
# 7      4.0    5.8    76         0.81
# 4      4.6    6.0    84         0.79
# 58     8.1    6.1   118         0.70
# 42     7.2    7.2   154         0.82
# 12     7.1    7.0   154         0.88
# 28     7.1    6.7   140         0.72
# 22     7.1    7.3   140         0.87
# 5      4.3    5.8    80         0.77
# 16     7.5    7.6   156         0.67
# 9      7.0    7.4   172         0.89
# ...

# %%
import pandas as pd
iris_data=pd.read_csv('C://Users//Bhavesh//iris.csv')

# %%
from sklearn.model_selection import train_test_split
iris_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
x=iris_data[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]
y=iris_data[['Species', ]]
x_train,x_test,y_train,y_test=train_test_split(x,y)

# %%
len(x_test)
# Out:
# 38

# %%
from scipy.spatial import distance

# %%
import numpy as  np
a=(2,5,8)
b=(9,6,3)
euc=distance.euclidean(a,b,3)
# Out:
# 15.0

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(x_train,y_train)
# Out:
# C:\Users\Bhavesh\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   """Entry point for launching an IPython kernel.
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
flowerpre=knn.predict([[0,4.3,100,0.72]])
flowerpre
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
accuracy=knn.score(x_test,y_test)
accuracy
# Out:
# 0.9473684210526315

# %%
from adspy_shared_utilities import plot_fruit_knn

plot_fruit_knn(x_train, y_train, 5, 'uniform')   # we choose 5 nearest neighbors
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-79-2e9dc0807047> in <module>
# ----> 1 from adspy_shared_utilities import plot_fruit_knn
#       2
#       3 plot_fruit_knn(x_train, y_train, 5, 'uniform')   # we choose 5 nearest neighbors
#
# ModuleNotFoundError: No module named 'adspy_shared_utilities'
