# %%
def convert_to_float(x):
    token=x.split('-')
    if len(token)==2:
        return (float(token[0])+float(token[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
convert_to_float('2100-2200')
# Out:
# 2150.0

# %%
def convert_sqft_to_num(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
convert_sqft_to_num('2100 - 2200')
# Out:
# 2150.0

# %%
x='bhavesh shama'
x.rstrip()
# Out:
# 'bhavesh shama'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C://Users//Bhavesh//bengluru_hp_clean1.csv')
df.head(50)
# Out:
#     Unnamed: 0                  location       size  total_sqft  bath   price  \
# 0            0  Electronic City Phase II      2 BHK     1056.00   2.0   39.07
# 1            1          Chikka Tirupathi  4 Bedroom     2600.00   5.0  120.00
# 2            2               Uttarahalli      3 BHK     1440.00   2.0   62.00
# 3            3        Lingadheeranahalli      3 BHK     1521.00   3.0   95.00
# 4            4                  Kothanur      2 BHK     1200.00   2.0   51.00
# 5            5                Whitefield      2 BHK     1170.00   2.0   38.00
# 6            6          Old Airport Road      4 BHK     2732.00   4.0  204.00
# 7            7              Rajaji Nagar      4 BHK     3300.00   4.0  600.00
# 8            8              Marathahalli      3 BHK     1310.00   3.0   63.25
# 9           10                Whitefield      3 BHK     1800.00   2.0   70.00
# 10          11                Whitefield  4 Bedroom     2785.00   5.0  295.00
# ...

# %%
print('shape is : ',df.shape)
#this is outlier, we know that not single bhk canbe developed less 400 
print(len(df[df['total_sqft']<400]))
# Out:
# shape is :  (13047, 8)
# 21

# %%
#so i am gonna remove that
df1=df[df['total_sqft']>400]
df1.sample(20)
# Out:
#        Unnamed: 0                location       size  total_sqft  bath  \
# 2975         3040                  Hebbal      3 BHK      1700.0   3.0
# 7817         7992                   other  2 Bedroom      1200.0   2.0
# 3273         3343                  Harlur  4 Bedroom      3385.0   4.0
# 10586       10814      1st Phase JP Nagar      2 BHK      1205.0   2.0
# 60             63                 Varthur      2 BHK      1160.0   2.0
# 3958         4045              R.T. Nagar  4 Bedroom      2000.0   4.0
# 12418       12671          Sarjapur  Road      2 BHK      1346.0   2.0
# 12891       13157                   other      2 BHK      1100.0   2.0
# 6684         6833   Raja Rajeshwari Nagar      2 BHK      1128.0   2.0
# 5000         5105                   other      2 BHK      1100.0   2.0
# 847           868                KR Puram      2 BHK      1225.0   2.0
# 8251         8438  Banashankari Stage III      2 BHK       910.0   2.0
# ...

# %%
df1.shape
13010-77
# Out:
# 12933

# %%
#creating a new column of where bhk/totalsqft .. which will give us sqft to create single bhk
#which we know is 400
df1['1bhk_area'] = df1.total_sqft / df1.bhk
# Out:
# C:\Users\Bhavesh\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df1.sample(20)
df1[(df1['1bhk_area']<100)]
#removing them
df2=df1[(df1['1bhk_area']>100)]
df.shape
# Out:
# (13047, 8)

# %%
df2[(df2['1bhk_area']<115)]
#removing them
df3=df2[(df2['1bhk_area']>115)]

# %%
df3.shape
# Out:
# (12956, 9)

# %%
df3.groupby('location')['location'].agg('count').sort_values(ascending=False)
# Out:
# location
# other                        2736
# Whitefield                    530
# Sarjapur  Road                391
# Electronic City               303
# Kanakpura Road                262
# Thanisandra                   235
# Yelahanka                     208
# Uttarahalli                   184
# Hebbal                        176
# Marathahalli                  175
# Raja Rajeshwari Nagar         170
# Bannerghatta Road             150
# Hennur Road                   149
# 7th Phase JP Nagar            147
# Haralur Road                  141
# Electronic City Phase II      130
# Rajaji Nagar                  102
# Chandapura                     98
# Bellandur                      94
# Hoodi                          88
# KR Puram                       87
# Electronics City Phase 1       86
# Begur Road                     84
# Yeshwanthpur                   84
# Sarjapur                       80
# Kasavanhalli                   79
# Harlur                         79
# ...

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sq),
                'std': np.std(bhk_df.price_per_sq),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats = bhk_stats.get(bhk-1)
            if stats and stats['count']>5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sq<(stats['mean'])].index.values)
    return df.drop(exclude_indices,axis='index')
df4 = remove_bhk_outliers(df3)
df4.shape
# Out:
# (9200, 9)

# %%
#plotting graph 
import matplotlib
def plot(df,location):
    bhk2=df[(df.location==location) & (df.bhk==2)]
    bhk3=df[(df.location==location) & (df.bhk==3)]
    plt.scatter(bhk2.total_sqft,bhk2.price,color='red',label='2bhk')
    plt.scatter(bhk3.total_sqft,bhk3.price,color='green',label='3bhk',marker='*')
    plt.xlabel('total_sqf')
    plt.ylabel('price')
    plt.title('location')
    plt.legend

# %%
plot(df4,'Rajaji Nagar')

# %%
#now removing outlier using 4 deviation 
upper_limit=df4.price_per_sq.mean() + 1*df4.price_per_sq.std()
lower_limit=df4.price_per_sq.mean() - 1*df4.price_per_sq.std()
print('upper limit : ',upper_limit)
print('lower limit : ',lower_limit)
# Out:
# upper limit :  10908.326000365849
# lower limit :  3411.390070277848

# %%
df5=df4[(df4['price_per_sq']<upper_limit) & (df4['price_per_sq']>lower_limit)]
df5.shape
# Out:
# (7391, 9)

# %%
plot(df5,'Rajaji Nagar')

# %%
for i in range(2):
    result='5 4 2 1'
return result
# Out:
#   File "<ipython-input-103-68444c8eca81>", line 3
#     return result
#                  ^
# SyntaxError: 'return' outside function

# %%
import json
file1=open('C://Users//Bhavesh//columns.json')
js_data=json.load(file1)
#type(js_data.items())
loc1=[]
for i in js_data:
    loc1.append(js_data[i])
for x in loc1:
    print(x)
tuple(x)
x[3:]
len(x)
# Out:
# ['total_sqft', 'bath', 'bhk', ' devarachikkanahalli', '1st block jayanagar', '1st phase jp nagar', '2nd phase judicial layout', '2nd stage nagarbhavi', '5th block hbr layout', '5th phase jp nagar', '6th phase jp nagar', '7th phase jp nagar', '8th phase jp nagar', '9th phase jp nagar', 'aecs layout', 'abbigere', 'akshaya nagar', 'ambalipura', 'ambedkar nagar', 'amruthahalli', 'anandapura', 'ananth nagar', 'anekal', 'anjanapura', 'ardendale', 'arekere', 'attibele', 'beml layout', 'btm 2nd stage', 'btm layout', 'babusapalaya', 'badavala nagar', 'balagere', 'banashankari', 'banashankari stage ii', 'banashankari stage iii', 'banashankari stage v', 'banashankari stage vi', 'banaswadi', 'banjara layout', 'bannerghatta', 'bannerghatta road', 'basavangudi', 'basaveshwara nagar', 'battarahalli', 'begur', 'begur road', 'bellandur', 'benson town', 'bharathi nagar', 'bhoganhalli', 'billekahalli', 'binny pete', 'bisuvanahalli', 'bommanahalli', 'bommasandra', 'bommasandra industrial area', 'bommena
# ...

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('C://Users//Bhavesh//cleaned_bhp.csv')
X = df.drop(['price'],axis='columns')
y = df.price
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=10)
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train,y_train)
lr_clf.score(X_test,y_test)
def predict_price(location,sqft,bath,bhk):    
    loc_index = np.where(X.columns==location)[0][0]

    x = np.zeros(len(X.columns))
    x[0] = sqft
    x[1] = bath
    x[2] = bhk
    if loc_index >= 0:
        x[loc_index] = 1

    return lr_clf.predict([x])[0]
#predict_price('Rajaji Nagar',1010,2,2)
    result=predict_price(location,sqft,bath,bhk)
#print(result)

# %%
predict_price('hebbal',5456,2,4)
# Out:
# -9.981364725151517

# %%
location='hebbal'
sqft=1589
bath=4
bhk=1
predict_price(location,sqft,bath,bhk)
# Out:
# -14.502570414140457
